# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#response = requests.get(query_url + "New York").json()
#pprint(response)
#response["main"]["temp_max"]
data = []
counter = 0
for city in cities[:600]:
    response = requests.get(query_url + city).json()
    counter = counter + 1
    try:
        max_temp = response["main"]["temp_max"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        clouds = response["clouds"]["all"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        country = response["sys"]["country"]
        data.append([city, country, date, latitude, longitude, max_temp, humidity, wind_speed, clouds])
        print(f"counter {counter} {city}")
        time.sleep(.2)
    except:
        print("City Not Found")
# Out:
# counter 1 lukhovitsy
# counter 2 ashland
# counter 3 hermanus
# counter 4 bethel
# counter 5 yellowknife
# counter 6 hobart
# counter 7 sarangani
# counter 8 cabo san lucas
# counter 9 mataura
# counter 10 rudbar
# counter 11 busselton
# counter 12 bengkulu
# counter 13 east london
# counter 14 san patricio
# counter 15 ilulissat
# counter 16 codrington
# counter 17 lobito
# counter 18 itirucu
# counter 19 quatre cocos
# City Not Found
# counter 21 acarau
# counter 22 tiksi
# counter 23 callaguip
# City Not Found
# counter 25 esperance
# counter 26 garowe
# counter 27 ushuaia
# counter 28 flinders
# City Not Found
# counter 30 port elizabeth
# counter 31 puerto ayora
# counter 32 thyboron
# counter 33 qaanaaq
# counter 34 albany
# counter 35 khani
# counter 36 saskylakh
# counter 37 qidong
# counter 38 zhigansk
# counter 39 bluff
# City Not Found
# counter 41 dikson
# counter 42 castro
# counter 43 vestmanna
# counter 44 hilo
# counter 45 new norfolk
# City Not Found
# counter 47 thompson
# counter 48 balakhninskiy
# counter 49 bambous virieux
# counter 50 punta arenas
# counter 51 south yuba city
# counter 52 tautira
# counter 53 rikitea
# counter 54 porsa
# counter 55 mar del plata
# counter 56 jamestown
# counter 57 kondinskoye
# counter 58 kaitangata
# counter 59 taksimo
# counter 60 ribeira grande
# City Not Found
# counter 62 saint george
# counter 63 canutama
# counter 64 waiouru
# counter 65 santa rita
# counter 66 arraial do cabo
# counter 67 portland
# counter 68 bredasdorp
# counter 69 stornoway
# counter 70 chokurdakh
# City Not Found
# counter 72 lebu
# counter 73 kapaa
# counter 74 carnarvon
# City Not Found
# counter 76 sabang
# counter 77 severodvinsk
# counter 78 joao pinheiro
# counter 79 itambacuri
# counter 80 barentu
# counter 81 atuona
# counter 82 saltillo
# counter 83 cidreira
# counter 84 the valley
# counter 85 komsomolskiy
# counter 86 airai
# counter 87 newport
# counter 88 vaini
# counter 89 maralal
# counter 90 nago
# counter 91 vestmannaeyjar
# counter 92 lagoa
# counter 93 axim
# counter 94 pathein
# counter 95 barcelos
# counter 96 halifax
# counter 97 upernavik
# counter 98 laguna
# counter 99 nanortalik
# 544       darhan      MN  1603913452     49.49     105.92     -0.03        83
# 545       kabale      UG  1603913452     -1.25      29.99     15.84        88
# 546      bogotol      RU  1603913452     56.21      89.53     -1.17        98
#
#      wind_speed  clouds
# 0          3.58       0
# 1          3.60      90
# 2          0.45      28
# 3          2.87      90
# 4          3.60      90
# ..          ...     ...
# 542        8.00      75
# 543        5.18     100
# 544        3.15       0
# 545        1.21      98
# 546        6.64     100
#
# [547 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydf.to_csv(output_data_file, index_label="cityid")

# %%
citydf.head()
# Out:
#           city country        date  latitude  longitude  max_temp  humidity  \
# 0   lukhovitsy      RU  1603913259     54.97      39.04      2.78        87
# 1      ashland      US  1603913260     40.82     -82.27     10.00        87
# 2     hermanus      ZA  1603913249    -34.42      19.23     17.78        62
# 3       bethel      US  1603913248     41.37     -73.41     11.11        93
# 4  yellowknife      CA  1603913261     62.46    -114.35     -4.00        73
#
#    wind_speed  clouds
# 0        3.58       0
# 1        3.60      90
# 2        0.45      28
# 3        2.87      90
# 4        3.60      90

# %%
citydf.count()
# Out:
# city          547
# country       547
# date          547
# latitude      547
# longitude     547
# max_temp      547
# humidity      547
# wind_speed    547
# clouds        547
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# There were no cities where the humidity was > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["max_temp"], facecolors="red", edgecolors="maroon")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature (F) on {today}", fontsize=12.25)
plt.savefig("Figures/LatitudeVsMaxTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["humidity"], facecolors="gray", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f" City Latitude vs. Humidity (%) on {today}", fontsize=14)
plt.savefig("Figures/LatitudeVsHumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["clouds"], facecolors="white", edgecolors="gray")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f" City Latitude vs. Cloudiness (%) on {today}", fontsize=13.5)
plt.savefig("Figures/LatitudeVsClouds.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["wind_speed"], facecolors="blue", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f" City Latitude vs. Wind Speed (mph) on {today}", fontsize=12.75)
plt.savefig("Figures/LatitudeVsWinds.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = citydf[citydf["latitude"]>=0]
northern_hem.count()
# Out:
# city          384
# country       384
# date          384
# latitude      384
# longitude     384
# max_temp      384
# humidity      384
# wind_speed    384
# clouds        384
# dtype: int64

# %%
southern_hem = citydf[citydf["latitude"]<0]
southern_hem.count()
# Out:
# city          163
# country       163
# date          163
# latitude      163
# longitude     163
# max_temp      163
# humidity      163
# wind_speed    163
# clouds        163
# dtype: int64

# %%
# Built a function that calculates the linear regression for each graph by allowing the unique x and y variables to be added
# their descriptions, specify the hemisphere location, save the graph as a unique file, and allow the linear regression to 
# be added to the graph by plotting it on x and y coordinates. This method allows me to have less fun with the variety of
# colors used in the graph, but is more efficient. Also added a function that states the r-squared value.

def lin_reg_plot(x_values, y_values, x_des, y_des, hemisphere, filename, x_cord,y_cord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression_values = x_values * slope + intercept
    equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values, facecolor='teal', edgecolors='black')
    plt.plot(x_values, regression_values,"r-")
    plt.title(f"{hemisphere}:\nCity {x_des} vs. {y_des} on {today}")
    plt.annotate(equation,(x_cord, y_cord), fontsize=15, color="red")
    plt.xlabel(x_des)
    plt.ylabel(y_des)
    print(f"The r-squared is: {rvalue}.")
    print(equation)
    plt.savefig(f'Figures/{filename}')
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["latitude"], northern_hem["max_temp"],\
                  'Latitude','Max Temperature (F)','Northern Hemisphere',\
                 'NorthernHemLatVsMaxTemp.png', 2, -10)
# Out:
# The r-squared is: -0.8783028944495329.
# y = -0.58x + 34.61

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["latitude"], southern_hem["max_temp"],\
                  'Latitude','Max Temperature (F)','Southern Hemisphere',\
                 'SouthernHemLatVsMaxTemp.png', -55, 30)
# Out:
# The r-squared is: 0.7191953215534111.
# y = 0.33x + 28.68

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["latitude"], northern_hem["humidity"],\
                  'Latitude','Humidity (%)','Northern Hemisphere',\
                 'NorthernHemLatVsHumidity.png', 43, 20)
# Out:
# The r-squared is: 0.33730044279190124.
# y = 0.36x + 57.88

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["latitude"], southern_hem["humidity"],\
                  'Latitude','Humidity (%)','Southern Hemisphere',\
                 'SouthernHemLatVsHumidity.png', -55, 20)
# Out:
# The r-squared is: 0.12815187404255535.
# y = 0.18x + 74.18

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["latitude"], northern_hem["clouds"],\
                  'Latitude','Cloudiness (%)','Northern Hemisphere',\
                 'NorthernHemLatVsClouds.png', 20, 60)
# Out:
# The r-squared is: 0.1802585520054116.
# y = 0.36x + 33.31

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["latitude"], southern_hem["clouds"],\
                  'Latitude','Cloudiness (%)','Southern Hemisphere',\
                 'SouthernHemLatVsClouds.png', -55, 43)
# Out:
# The r-squared is: -0.035927814105320845.
# y = -0.11x + 51.08

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["latitude"], northern_hem["wind_speed"],\
                  'Latitude','Wind Speed (mph)','Northern Hemisphere',\
                 'NorthernHemLatVsWinds.png', 23, 13)
# Out:
# The r-squared is: 0.16592231192451545.
# y = 0.02x + 2.65

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["latitude"], southern_hem["wind_speed"],\
                  'Latitude','Wind Speed (mph)','Southern Hemisphere',\
                 'SouthernHemLatVsWinds.png', -50, 9.75)
# Out:
# The r-squared is: -0.05488387095796913.
# y = -0.01x + 3.65
