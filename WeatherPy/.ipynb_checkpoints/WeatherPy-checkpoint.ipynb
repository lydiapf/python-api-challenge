# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#response = requests.get(query_url + "New York").json()
#pprint(response)
#response["main"]["temp_max"]
data = []
counter = 0
for city in cities[:600]:
    response = requests.get(query_url + city).json()
    counter = counter + 1
    try:
        max_temp = response["main"]["temp_max"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        clouds = response["clouds"]["all"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        country = response["sys"]["country"]
        data.append([city, country, date, latitude, longitude, max_temp, humidity, wind_speed, clouds])
        print(f"counter {counter} {city}")
        time.sleep(.2)
    except:
        print("City Not Found")
# Out:
# counter 1 chaah
# counter 2 ushuaia
# counter 3 arraial do cabo
# counter 4 smithers
# counter 5 yilan
# counter 6 ahipara
# counter 7 cabinda
# counter 8 dikson
# counter 9 airai
# counter 10 biak
# City Not Found
# counter 12 bengkulu
# counter 13 vaini
# counter 14 nhulunbuy
# counter 15 kapaa
# counter 16 youghal
# counter 17 grand gaube
# counter 18 doka
# counter 19 hithadhoo
# counter 20 puerto ayora
# counter 21 panguna
# counter 22 harnosand
# counter 23 tessalit
# City Not Found
# counter 25 saldanha
# counter 26 kibre mengist
# counter 27 yellowknife
# counter 28 rikitea
# counter 29 phirangipuram
# counter 30 port alfred
# counter 31 listvyagi
# counter 32 cavalcante
# counter 33 bethel
# City Not Found
# counter 35 kandrian
# City Not Found
# counter 37 cape town
# counter 38 ilulissat
# counter 39 carnarvon
# counter 40 pandan
# counter 41 eyl
# counter 42 saint-philippe
# counter 43 los llanos de aridane
# counter 44 salinas
# counter 45 mikhaylovskoye
# counter 46 yar-sale
# City Not Found
# counter 48 punta arenas
# counter 49 castro
# counter 50 tuktoyaktuk
# counter 51 husavik
# counter 52 hermanus
# counter 53 san andres
# counter 54 namtsy
# counter 55 hilo
# counter 56 pevek
# counter 57 debre birhan
# counter 58 mao
# counter 59 norman wells
# counter 60 barrow
# counter 61 guerrero negro
# counter 62 vicuna
# counter 63 pell city
# City Not Found
# counter 65 salamanca
# counter 66 bluff
# counter 67 nyurba
# counter 68 kaitangata
# counter 69 east london
# counter 70 vila
# counter 71 zhengjiatun
# counter 72 amapa
# counter 73 bredasdorp
# counter 74 ancud
# counter 75 gazli
# counter 76 broome
# counter 77 qaanaaq
# counter 78 talnakh
# counter 79 mount gambier
# counter 80 albany
# counter 81 atuona
# counter 82 hamilton
# counter 83 mataura
# counter 84 thompson
# counter 85 busselton
# counter 86 rapar
# counter 87 sitka
# City Not Found
# counter 89 maymyo
# counter 90 sehithwa
# counter 91 laguna de perlas
# counter 92 san juan
# counter 93 altamira
# counter 94 nalut
# counter 95 clyde river
# counter 96 monroe
# counter 97 kavaratti
# counter 98 ponerihouen
# counter 99 cidreira
# counter 100 america dourada
# counter 101 ravar
# counter 102 tiksi
# City Not Found
# counter 104 hobart
# City Not Found
# counter 106 saint-pierre
# counter 107 lavrentiya
# counter 108 upernavik
# counter 109 lashio
# counter 110 maracai
# counter 111 omboue
# counter 112 kodiak
# counter 113 cozumel
# counter 114 beloha
# counter 115 kruisfontein
# City Not Found
# counter 117 honiara
# counter 118 deputatskiy
# counter 119 daokou
# counter 120 suntar
# counter 121 avarua
# counter 122 kenai
# counter 123 butaritari
# counter 124 rocha
# counter 125 narsaq
# counter 126 alice springs
# counter 127 marmarion
# counter 128 victoria
# counter 129 trapani
# counter 130 havoysund
# counter 131 khatanga
# counter 132 lebu
# counter 133 lagoa
# counter 134 mezen
# counter 135 hofn
# counter 136 grindavik
# counter 137 mount isa
# counter 138 bure
# counter 139 salme
# counter 140 mangrol
# counter 141 ribeira grande
# counter 142 tautira
# counter 143 port blair
# counter 144 polunochnoye
# counter 145 fortuna
# counter 146 torbay
# counter 147 san carlos de bariloche
# counter 148 karoi
# counter 149 ponta do sol
# counter 150 nkan
# counter 151 padang
# counter 152 iqaluit
# counter 153 bathsheba
# counter 154 invermere
# counter 155 ugoofaaru
# counter 156 patnos
# counter 157 ukiah
# counter 158 kahului
# counter 159 lompoc
# counter 160 rocky mountain house
# counter 161 nanortalik
# counter 162 makakilo city
# counter 163 cayenne
# counter 164 kathu
# counter 165 palasa
# counter 166 cherskiy
# counter 167 bireun
# counter 168 laguna
# counter 169 camocim
# counter 170 chokurdakh
# counter 171 aguimes
# counter 172 bud
# counter 173 savona
# counter 174 mabay
# counter 175 avera
# counter 176 leningradskiy
# counter 177 bambous virieux
# counter 178 codrington
# counter 179 marawi
# counter 180 swift current
# counter 181 valparaiso
# City Not Found
# counter 183 ust-maya
# counter 184 taltal
# counter 185 kaspiysk
# counter 186 moose factory
# counter 187 ormara
# counter 188 xiaoyi
# counter 189 pozo colorado
# counter 190 le port
# counter 191 urumqi
# counter 192 hobyo
# counter 193 tecoanapa
# counter 194 korla
# counter 195 kununurra
# counter 196 rio gallegos
# counter 197 eureka
# counter 198 tahoua
# counter 199 novaya zaimka
# counter 200 acarau
# counter 201 chifeng
# counter 202 santa marta
# counter 203 tsaratanana
# counter 204 matata
# counter 205 mar del plata
# counter 206 bukama
# counter 207 mahebourg
# counter 208 careiro da varzea
# counter 209 antofagasta
# City Not Found
# counter 211 tabou
# counter 212 jamestown
# counter 213 bongor
# counter 214 vinh yen
# counter 215 kajaani
# counter 216 menongue
# counter 217 vila velha
# City Not Found
# counter 219 slyudyanka
# counter 220 port elizabeth
# City Not Found
# counter 222 tasiilaq
# counter 223 laukaa
# counter 224 nikolskoye
# counter 225 lagos
# counter 226 valle hermoso
# counter 227 namibe
# counter 228 coahuayana
# City Not Found
# counter 230 muros
# counter 231 madingou
# counter 232 timra
# counter 233 vrangel
# counter 234 puerto rondon
# counter 235 paamiut
# counter 236 naze
# counter 237 natal
# City Not Found
# counter 239 souillac
# counter 240 marsabit
# counter 241 orlik
# counter 242 kungurtug
# counter 243 inirida
# City Not Found
# counter 245 new norfolk
# counter 246 maniitsoq
# counter 247 gulu
# counter 248 kindu
# City Not Found
# City Not Found
# counter 251 port lincoln
# counter 252 oktyabrskoye
# counter 253 aquiraz
# counter 254 guangzhou
# counter 255 luena
# counter 256 bratsk
# counter 257 coquimbo
# counter 258 saint george
# counter 259 kloulklubed
# City Not Found
# counter 261 irbeyskoye
# counter 262 chase
# counter 263 mahanoro
# counter 264 lere
# counter 265 flin flon
# counter 266 big rapids
# counter 267 oyama
# counter 268 manono
# counter 269 necochea
# counter 270 ocos
# counter 271 sola
# counter 272 tuatapere
# counter 273 musiri
# counter 274 dauphin
# counter 275 senekal
# City Not Found
# City Not Found
# counter 278 erzin
# counter 279 faanui
# counter 280 tadine
# counter 281 provideniya
# counter 282 san luis
# counter 283 vostok
# counter 284 port-gentil
# counter 285 rudersdorf
# counter 286 rawson
# counter 287 xiongyue
# counter 288 northam
# counter 289 roma
# counter 290 itupiranga
# counter 291 petropavlovsk-kamchatskiy
# counter 292 launceston
# counter 293 laramie
# counter 294 otjimbingwe
# counter 295 high level
# counter 296 esperance
# counter 297 mandurah
# counter 298 semporna
# counter 299 buala
# counter 300 bosaso
# counter 301 cabo san lucas
# counter 302 kottagudem
# counter 303 faya
# counter 304 altay
# counter 305 matara
# counter 306 kupang
# counter 307 vestmannaeyjar
# counter 308 baruun-urt
# counter 309 chapais
# counter 310 mopipi
# counter 311 havelock
# counter 312 vilhena
# counter 313 macamic
# counter 314 haines junction
# counter 315 chuy
# counter 316 ca mau
# counter 317 caraquet
# City Not Found
# counter 319 nichinan
# counter 320 karratha
# counter 321 hasaki
# counter 322 skelleftea
# counter 323 ayan
# counter 324 kijang
# counter 325 carutapera
# counter 326 tha chang
# counter 327 montepulciano
# counter 328 olafsvik
# counter 329 portland
# counter 330 ararangua
# counter 331 marystown
# counter 332 mankono
# counter 333 waddan
# counter 334 sinnamary
# counter 335 karasjok
# counter 336 turkan
# counter 337 waingapu
# counter 338 berezovyy
# counter 339 bilma
# counter 340 chilca
# counter 341 sistranda
# counter 342 panzhihua
# City Not Found
# counter 344 pula
# counter 345 almeirim
# counter 346 najran
# counter 347 gravelbourg
# counter 348 newport
# counter 349 kaihua
# counter 350 cam ranh
# counter 351 encheng
# counter 352 kiruna
# counter 353 rio grande
# City Not Found
# counter 355 dingle
# counter 356 khotyn
# counter 357 zhigansk
# counter 358 saskylakh
# counter 359 champerico
# counter 360 boyolangu
# City Not Found
# City Not Found
# counter 363 okha
# counter 364 kulhudhuffushi
# counter 365 tura
# counter 366 berlevag
# counter 367 kutum
# counter 368 brownsville
# counter 369 porbandar
# counter 370 pakala
# counter 371 buraydah
# counter 372 cacu
# counter 373 tazovskiy
# counter 374 georgetown
# counter 375 takaka
# counter 376 chebsara
# counter 377 linxia
# counter 378 palmer
# counter 379 havre-saint-pierre
# counter 380 mayskiy
# counter 381 port macquarie
# City Not Found
# counter 383 constitucion
# counter 384 caxito
# counter 385 dafeng
# counter 386 santa maria
# counter 387 petukhovo
# City Not Found
# counter 389 segou
# counter 390 hirosaki
# counter 391 roald
# counter 392 bonthe
# counter 393 toamasina
# counter 394 marzuq
# counter 395 saint-georges
# counter 396 cooma
# counter 397 verkhoyansk
# counter 398 hjelset
# counter 399 gaoua
# counter 400 baiyin
# counter 401 ha tinh
# counter 402 manado
# counter 403 williston
# counter 404 dharchula
# counter 405 jamalpur
# counter 406 magaria
# counter 407 pisco
# counter 408 alta floresta
# counter 409 samarai
# City Not Found
# counter 411 cabatuan
# counter 412 mason city
# counter 413 jieshi
# counter 414 shaunavon
# counter 415 upata
# counter 416 kidal
# City Not Found
# counter 418 ziarat
# counter 419 amol
# counter 420 meulaboh
# counter 421 kavieng
# counter 422 khakhea
# counter 423 moree
# counter 424 assiniboia
# counter 425 baykit
# counter 426 bolkhov
# counter 427 north bend
# counter 428 praia da vitoria
# counter 429 pacific grove
# counter 430 tiznit
# counter 431 mbandaka
# City Not Found
# counter 433 pedernales
# City Not Found
# City Not Found
# counter 436 beira
# counter 437 katsuura
# counter 438 sorland
# counter 439 barstow
# counter 440 mnogovershinnyy
# counter 441 yulara
# counter 442 barranca
# counter 443 kabalo
# counter 444 bo phloi
# counter 445 gambo
# counter 446 bagdarin
# counter 447 mogadishu
# counter 448 gobabis
# counter 449 nisia floresta
# counter 450 ixtapa
# counter 451 dillingen
# counter 452 qasigiannguit
# City Not Found
# counter 454 asau
# counter 455 ishigaki
# counter 456 praia
# counter 457 ivybridge
# counter 458 vardo
# counter 459 abha
# counter 460 plettenberg bay
# counter 461 bandarbeyla
# counter 462 mbaiki
# counter 463 jalalabad
# City Not Found
# counter 465 bulgan
# counter 466 saint-francois
# counter 467 markova
# counter 468 sobolevo
# counter 469 banes
# counter 470 sarkand
# counter 471 morelia
# counter 472 severo-kurilsk
# counter 473 ogori
# counter 474 gweru
# counter 475 mayo
# counter 476 muroto
# City Not Found
# counter 478 kimbe
# counter 479 abnub
# counter 480 szigetvar
# counter 481 richards bay
# counter 482 imeni babushkina
# counter 483 manadhoo
# counter 484 labytnangi
# counter 485 loten
# counter 486 kotido
# counter 487 yumen
# counter 488 birao
# counter 489 luanda
# City Not Found
# counter 491 morant bay
# counter 492 birin
# counter 493 longyearbyen
# counter 494 namatanai
# counter 495 koungheul
# counter 496 tommot
# counter 497 christchurch
# counter 498 pilar
# counter 499 sudak
# counter 500 udachnyy
# counter 501 milkovo
# counter 502 talara
# City Not Found
# counter 504 baracoa
# counter 505 banjar
# counter 506 hokitika
# counter 507 teya
# counter 508 selestat
# counter 509 shetpe
# counter 510 saint-avold
# counter 511 bismarck
# counter 512 okhotsk
# counter 513 sfantu gheorghe
# counter 514 beinamar
# counter 515 sedalia
# counter 516 henties bay
# City Not Found
# counter 518 buchanan
# counter 519 saint-paul
# counter 520 san patricio
# City Not Found
# counter 522 podporozhye
# counter 523 elban
# counter 524 manaus
# counter 525 sioux lookout
# counter 526 arrifes
# counter 527 mogzon
# counter 528 muli
# counter 529 aljezur
# counter 530 baijiantan
# counter 531 mangai
# City Not Found
# counter 533 yashkul
# counter 534 riyadh
# counter 535 acapulco
# counter 536 wyndham
# counter 537 ponnampet
# counter 538 hami
# counter 539 nizhniy tsasuchey
# counter 540 livingston
# counter 541 fond du lac
# counter 542 panama city
# counter 543 lazaro cardenas
# counter 544 daru
# counter 545 caravelas
# counter 546 tanda
# counter 547 khorixas
# counter 548 pokhara
# counter 549 tilichiki
# counter 550 maracineni
# counter 551 bela vista
# counter 552 katherine
# City Not Found
# counter 554 san jeronimo
# counter 555 isangel
# counter 556 ngunguru
# counter 557 sikandarabad
# City Not Found
# City Not Found
# counter 560 rock sound
# counter 561 alenquer
# counter 562 zhangye
# counter 563 sinjar
# counter 564 lebork
# City Not Found
# counter 566 porto murtinho
# counter 567 diepholz
# counter 568 hailar
# counter 569 tobolsk
# counter 570 brejinho
# counter 571 raga
# counter 572 deli tua
# counter 573 aklavik
# counter 574 denpasar
# counter 575 gold coast
# counter 576 bontang
# counter 577 gat
# counter 578 byron bay
# counter 579 pantai remis
# counter 580 beberibe
# counter 581 pangnirtung
# counter 582 mandalgovi
# counter 583 zavetnoye
# counter 584 neiafu
# counter 585 jatai
# counter 586 tezu
# counter 587 nome
# counter 588 skjervoy
# counter 589 ambilobe
# counter 590 eau claire
# counter 591 nouadhibou
# counter 592 kitsuki
# counter 593 piacabucu
# counter 594 coaldale
# counter 595 ulaangom
# counter 596 sam roi yot
# counter 597 filadelfia
# counter 598 geraldton
# counter 599 kondinskoye
# counter 600 paray-le-monial

# %%
citydf = pd.DataFrame(data, columns=["city", "country", "date", "Lat", "Lng", "max_temp", "humidity", "wind_speed", "clouds"])

citydf
# Out:
#                 city country        date    Lat     Lng  max_temp  humidity  \
# 0              chaah      MY  1603936972   2.25  103.05     86.27        64
# 1            ushuaia      AR  1603936509 -54.80  -68.30     41.00        93
# 2    arraial do cabo      BR  1603936514 -22.97  -42.03     74.98        94
# 3           smithers      CA  1603936973  54.78 -127.17     33.80       100
# 4              yilan      TW  1603936973  24.76  121.75     79.00        99
# ..               ...     ...         ...    ...     ...       ...       ...
# 549      sam roi yot      TH  1603937167  12.27   99.87     81.30        79
# 550       filadelfia      US  1603936949  39.95  -75.16     59.00        77
# 551        geraldton      AU  1603937168 -28.77  114.60     84.20        26
# 552      kondinskoye      RU  1603937168  59.65   67.41     32.47        97
# 553  paray-le-monial      FR  1603937169  46.45    4.12     53.01        93
#
#      wind_speed  clouds
# 0          4.05      86
# 1         20.80      90
# 2          8.68       3
# 3          4.70      90
# 4          5.35     100
# ..          ...     ...
# 549        3.11     100
# 550        3.36      90
# 551       13.87       0
# 552       12.48     100
# 553        5.82      75
#
# [554 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydf.to_csv(output_data_file, index_label="cityid")

# %%
citydf.head()
# Out:
#               city country        date    Lat     Lng  max_temp  humidity  \
# 0            chaah      MY  1603936972   2.25  103.05     86.27        64
# 1          ushuaia      AR  1603936509 -54.80  -68.30     41.00        93
# 2  arraial do cabo      BR  1603936514 -22.97  -42.03     74.98        94
# 3         smithers      CA  1603936973  54.78 -127.17     33.80       100
# 4            yilan      TW  1603936973  24.76  121.75     79.00        99
#
#    wind_speed  clouds
# 0        4.05      86
# 1       20.80      90
# 2        8.68       3
# 3        4.70      90
# 4        5.35     100

# %%
citydf.count()
# Out:
# city          554
# country       554
# date          554
# Lat           554
# Lng           554
# max_temp      554
# humidity      554
# wind_speed    554
# clouds        554
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# There were no cities where the humidity was > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["Lat"], citydf["max_temp"], facecolors="red", edgecolors="maroon")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature (F) on {today}", fontsize=12.25)
plt.savefig("Figures/LatitudeVsMaxTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["Lat"], citydf["humidity"], facecolors="gray", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f" City Latitude vs. Humidity (%) on {today}", fontsize=14)
plt.savefig("Figures/LatitudeVsHumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["Lat"], citydf["clouds"], facecolors="white", edgecolors="gray")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f" City Latitude vs. Cloudiness (%) on {today}", fontsize=13.5)
plt.savefig("Figures/LatitudeVsClouds.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["Lat"], citydf["wind_speed"], facecolors="blue", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f" City Latitude vs. Wind Speed (mph) on {today}", fontsize=12.75)
plt.savefig("Figures/LatitudeVsWinds.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = citydf[citydf["Lat"]>=0]
northern_hem.count()
# Out:
# city          384
# country       384
# date          384
# Lat           384
# Lng           384
# max_temp      384
# humidity      384
# wind_speed    384
# clouds        384
# dtype: int64

# %%
southern_hem = citydf[citydf["Lat"]<0]
southern_hem.count()
# Out:
# city          170
# country       170
# date          170
# Lat           170
# Lng           170
# max_temp      170
# humidity      170
# wind_speed    170
# clouds        170
# dtype: int64

# %%
# Built a function that calculates the linear regression for each graph by allowing the unique x and y variables to be added
# their descriptions, specify the hemisphere location, save the graph as a unique file, and allow the linear regression to 
# be added to the graph by plotting it on x and y coordinates. This method allows me to have less fun with the variety of
# colors used in the graph, but is more efficient. Also added a function that states the r-squared value.

def lin_reg_plot(x_values, y_values, x_des, y_des, hemisphere, filename, x_cord,y_cord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression_values = x_values * slope + intercept
    equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values, facecolor='teal', edgecolors='black')
    plt.plot(x_values, regression_values,"r-")
    plt.title(f"{hemisphere}:\nCity {x_des} vs. {y_des} on {today}")
    plt.annotate(equation,(x_cord, y_cord), fontsize=15, color="red")
    plt.xlabel(x_des)
    plt.ylabel(y_des)
    print(f"The r-squared is: {rvalue}.")
    print(equation)
    plt.savefig(f'Figures/{filename}')
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["Lat"], northern_hem["max_temp"],\
                  'Latitude','Max Temperature (F)','Northern Hemisphere',\
                 'NorthernHemLatVsMaxTemp.png', 2, 0)
# Out:
# The r-squared is: -0.8718742838127989.
# y = -0.96x + 89.33

# %%
print("There is a strong negative correlation between city latitude and maximum temperature. As one moves further north") 
print("from the equator, due to the tilt of the Earth’s axis, maximum temperatures decrease due to the angle at which the")
print("Sun warms the Earth. The r-squared values shows us that 87% of the data explains all the variability of the")
print("response data around its mean.")
# Out:
# There is a strong negative correlation between city latitude and maximum temperature. As one moves further north
# from the equator, due to the tilt of the Earth’s axis, maximum temperatures decrease due to the angle at which the
# Sun warms the Earth. The r-squared values shows us that 87% of the data explains all the variability of the
# response data around its mean.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["Lat"], southern_hem["max_temp"],\
                  'Latitude','Max Temperature (F)','Southern Hemisphere',\
                 'SouthernHemLatVsMaxTemp.png', -55, 85)
# Out:
# The r-squared is: 0.6871729096847183.
# y = 0.57x + 82.51

# %%
print("There is a strong positive correlation between city latitude and maximum temperature. As one moves closer to the") 
print("equator from the south, due to the tilt of the Earth’s axis, maximum temperatures increase due to the angle")
print("the Sun warms the Earth. The r-squared values shows us that 68% of the data explains all the variability of the") 
print("response data around its mean.")
# Out:
# There is a strong positive correlation between city latitude and maximum temperature. As one moves closer to the
# equator from the south, due to the tilt of the Earth’s axis, maximum temperatures increase due to the angle at which
# the Sun warms the Earth. The r-squared values shows us that 87% of the data explains all the variability of the
# response data around its mean.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["Lat"], northern_hem["humidity"],\
                  'Latitude','Humidity (%)','Northern Hemisphere',\
                 'NorthernHemLatVsHumidity.png', 43, 20)
# Out:
# The r-squared is: 0.24003389068870534.
# y = 0.23x + 66.86

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["Lat"], southern_hem["humidity"],\
                  'Latitude','Humidity (%)','Southern Hemisphere',\
                 'SouthernHemLatVsHumidity.png', -55, 18)
# Out:
# The r-squared is: 0.16372855558913496.
# y = 0.24x + 76.86

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["Lat"], northern_hem["clouds"],\
                  'Latitude','Cloudiness (%)','Northern Hemisphere',\
                 'NorthernHemLatVsClouds.png', 45, 10)
# Out:
# The r-squared is: 0.2059845099140487.
# y = 0.41x + 35.39

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["Lat"], southern_hem["clouds"],\
                  'Latitude','Cloudiness (%)','Southern Hemisphere',\
                 'SouthernHemLatVsClouds.png', -55, 34)
# Out:
# The r-squared is: 0.06460980457474107.
# y = 0.19x + 54.24

# %%
print("There is almost no correlation between city latitude and cloudiness. As one moves closer to the equator from") 
print("the south, this has little impact on the percentage of cloud cover.")
print("The r-squared values shows us that 6% of the data explains all the variability of the response data around") 
print("its mean. Thus implying that the model does not explain any of the variance and therefore there is no correlation.")
# Out:
# There is almost no correlation between city latitude and cloudiness. As one moves closer to the equator from
# the south, this has little impact on the percentage of cloud cover.
# The r-squared values shows us that 6% of the data explains all the variability of the response data around
# its mean. Thus implying that the model does not explain any of the variance and therefore there is no correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lin_reg_plot(northern_hem["Lat"], northern_hem["wind_speed"],\
                  'Latitude','Wind Speed (mph)','Northern Hemisphere',\
                 'NorthernHemLatVsWinds.png', 23, 30)
# Out:
# The r-squared is: 0.20651665468398664.
# y = 0.06x + 4.99

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lin_reg_plot(southern_hem["Lat"], southern_hem["wind_speed"],\
                  'Latitude','Wind Speed (mph)','Southern Hemisphere',\
                 'SouthernHemLatVsWinds.png', -40, 25)
# Out:
# The r-squared is: -0.29089517725836184.
# y = -0.11x + 5.49
