# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#response = requests.get(query_url + "New York").json()
#pprint(response)
#response["main"]["temp_max"]
data = []
counter = 0
for city in cities[:600]:
    response = requests.get(query_url + city).json()
    counter = counter + 1
    try:
        max_temp = response["main"]["temp_max"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        clouds = response["clouds"]["all"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        country = response["sys"]["country"]
        data.append([city, country, date, latitude, longitude, max_temp, humidity, wind_speed, clouds])
        print(f"counter {counter} {city}")
        time.sleep(.2)
    except:
        print("City Not Found")
# Out:
# counter 1 albany
# counter 2 ambatondrazaka
# counter 3 shingu
# counter 4 road town
# counter 5 pevek
# counter 6 haines junction
# counter 7 fecamp
# counter 8 khash
# City Not Found
# counter 10 padang
# counter 11 hithadhoo
# counter 12 busselton
# counter 13 novyy chirkey
# counter 14 yar-sale
# counter 15 ushuaia
# counter 16 cherskiy
# counter 17 namatanai
# counter 18 punta arenas
# counter 19 esperance
# counter 20 nikolskoye
# counter 21 andili
# counter 22 iqaluit
# counter 23 yerofey pavlovich
# counter 24 eyl
# counter 25 rikitea
# counter 26 port elizabeth
# counter 27 manono
# counter 28 sadiqabad
# counter 29 coquimbo
# counter 30 sao filipe
# counter 31 butaritari
# counter 32 hobart
# counter 33 tromso
# counter 34 port alfred
# counter 35 tecoanapa
# counter 36 victoria
# counter 37 mataura
# counter 38 emerald
# counter 39 carnarvon
# counter 40 nishihara
# counter 41 puerto ayora
# counter 42 kerman
# counter 43 cape town
# counter 44 lakatoro
# counter 45 price
# counter 46 qaanaaq
# counter 47 turukhansk
# counter 48 cidreira
# counter 49 bethel
# counter 50 stykkisholmur
# counter 51 san cristobal
# counter 52 faya
# counter 53 bluff
# counter 54 emba
# counter 55 tiksi
# counter 56 palana
# counter 57 port hardy
# counter 58 tibati
# counter 59 bushehr
# counter 60 beloha
# counter 61 hermanus
# counter 62 port blair
# counter 63 jamestown
# counter 64 sattahip
# counter 65 coahuayana
# counter 66 birnin kebbi
# City Not Found
# City Not Found
# counter 69 chara
# counter 70 kruisfontein
# City Not Found
# counter 72 tasiilaq
# counter 73 bathsheba
# counter 74 berezovyy
# counter 75 vaini
# counter 76 sakakah
# counter 77 kavaratti
# counter 78 muri
# counter 79 maniitsoq
# counter 80 upernavik
# counter 81 tuktoyaktuk
# City Not Found
# counter 83 hilo
# counter 84 christchurch
# counter 85 baiyin
# counter 86 mahibadhoo
# counter 87 inhambane
# counter 88 high level
# counter 89 alofi
# counter 90 hobyo
# City Not Found
# counter 92 kayes
# counter 93 chokurdakh
# counter 94 dallas
# counter 95 klaksvik
# counter 96 kapaa
# counter 97 esso
# counter 98 chingola
# City Not Found
# counter 100 karaton
# counter 101 umm kaddadah
# City Not Found
# counter 103 provideniya
# City Not Found
# counter 105 marystown
# counter 106 popondetta
# counter 107 nioro
# counter 108 tabou
# counter 109 sitka
# City Not Found
# counter 111 la union
# counter 112 souillac
# counter 113 aripuana
# counter 114 chitral
# counter 115 narasannapeta
# counter 116 torbay
# counter 117 nanortalik
# counter 118 svetlaya
# counter 119 borgloon
# counter 120 plastun
# counter 121 mahajanga
# counter 122 chaoyang
# City Not Found
# counter 124 grand gaube
# City Not Found
# counter 126 gizo
# counter 590 wairoa
# counter 591 jacareacanga
# counter 592 atambua
# City Not Found
# counter 594 palmer
# City Not Found
# counter 596 imbituba
# counter 597 little current
# counter 598 leninogorsk
# counter 599 ossora
# counter 600 lompoc

# %%
citydf = pd.DataFrame(data, columns=["city", "country", "date", "latitude", "longitude", "max_temp", "humidity", "wind_speed", "clouds"])

citydf
# Out:
#                city country        date  latitude  longitude  max_temp  \
# 0            albany      US  1603753950     42.60     -73.97     10.00
# 1    ambatondrazaka      MG  1603754153    -17.83      48.42     15.59
# 2            shingu      JP  1603754153     33.73     135.98     14.00
# 3         road town      VG  1603754155     18.42     -64.62     28.00
# 4             pevek      RU  1603754156     69.70     170.31     -4.98
# ..              ...     ...         ...       ...        ...       ...
# 549        imbituba      BR  1603754160    -28.24     -48.67     23.00
# 550  little current      CA  1603754336     45.98     -81.92      2.00
# 551     leninogorsk      RU  1603754337     54.60      52.46     -2.13
# 552          ossora      RU  1603754337     59.24     163.07      3.73
# 553          lompoc      US  1603754075     34.64    -120.46     21.00
#
#      humidity  wind_speed  clouds
# 0          98        0.89     100
# 1          91        0.97      56
# 2          58        4.60      20
# 3          83        5.70      40
# 4          94        8.08      98
# ..        ...         ...     ...
# 549        83        4.10      40
# 550        80        3.10      90
# 551        92        5.26      88
# 552        93        5.25     100
# 553        40        6.70       1
#
# [554 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydf.to_csv(output_data_file, index_label="cityid")

# %%
citydf.head()
# Out:
#              city country        date  latitude  longitude  max_temp  \
# 0          albany      US  1603753950     42.60     -73.97     10.00
# 1  ambatondrazaka      MG  1603754153    -17.83      48.42     15.59
# 2          shingu      JP  1603754153     33.73     135.98     14.00
# 3       road town      VG  1603754155     18.42     -64.62     28.00
# 4           pevek      RU  1603754156     69.70     170.31     -4.98
#
#    humidity  wind_speed  clouds
# 0        98        0.89     100
# 1        91        0.97      56
# 2        58        4.60      20
# 3        83        5.70      40
# 4        94        8.08      98

# %%
citydf.count()
# Out:
# city          554
# country       554
# date          554
# latitude      554
# longitude     554
# max_temp      554
# humidity      554
# wind_speed    554
# clouds        554
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# There were no cities where the humidity was > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["max_temp"], facecolors="red", edgecolors="maroon")
plt.xlabel("Latitude")
plt.ylabel("Highest Temperature (F)")
plt.title(f"Latitude of Cities vs. Highest Temperature (F) ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["humidity"], facecolors="gray", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f" Latitude of Cities vs. Humidity (%) ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["clouds"], facecolors="white", edgecolors="gray")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f" Latitude of Cities vs. Cloudiness (%) ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(citydf["latitude"], citydf["wind_speed"], facecolors="blue", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f" Latitude of Cities vs. Wind Speed (mph) ({today})")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = citydf[citydf["latitude"]>=0]
northern_hem.count()
# Out:
# city          386
# country       386
# date          386
# latitude      386
# longitude     386
# max_temp      386
# humidity      386
# wind_speed    386
# clouds        386
# dtype: int64

# %%
southern_hem = citydf[citydf["latitude"]<0]
southern_hem.count()
# Out:
# city          168
# country       168
# date          168
# latitude      168
# longitude     168
# max_temp      168
# humidity      168
# wind_speed    168
# clouds        168
# dtype: int64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
